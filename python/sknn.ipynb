# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors, datasets

df = pd.read_csv("sim_data.csv")
plt.figure(figsize=(25,5))
plt.plot(df.iloc[:200, :].T)
plt.show()
